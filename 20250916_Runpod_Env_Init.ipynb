# %%
# !pip install -q pandas sentence_transformers google-cloud-vision google-auth google-api-python-client
# !pip install -q langgraph dotenv langchain_openai langchain-community
# !pip install -q gradio

# %% [markdown]
# # .env 파일 사용이 어려운 경우(runpod, colab등에서 root 경로라 .으로 시작하는 히든파일이 보이지 않은 경우) .env 파일을 다른 이름으로 변경(ex:file.env) Allerguard_V1.py 에 있는 load_env() 에 파라메터로 해당 파일 경로와 이름을 지정해서 실행할것

# %%
import AllerGuard_gradio

demo.queue().launch(share=True)

# %%
import gradio as gr

gr.close_all()
